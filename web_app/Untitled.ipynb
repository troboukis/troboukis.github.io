# %%
import pandas as pd
import sqlite3

# %%
# Read in your file
df = pd.read_csv("death_un.csv")

# Connect to a database, a file called school_data.db
conn = sqlite3.connect("death.db")

# Save into a table called 'schools'
df.to_sql('death', conn)
# Out:
# /Users/viceproduction/.pyenv/versions/3.6.4/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (1,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#          Country  Year   Area         Sex    Age  \
# 0  Åland Islands  2015  Total  Both Sexes  Total
# 1  Åland Islands  2015  Total  Both Sexes      0
# 2  Åland Islands  2015  Total  Both Sexes      1
# 3  Åland Islands  2015  Total  Both Sexes  1 - 4
# 4  Åland Islands  2015  Total  Both Sexes      2
#
#                             Record_Type             Reliability  Source_Year  \
# 0  Data tabulated by year of occurrence  Final figure, complete       2017.0
# 1  Data tabulated by year of occurrence  Final figure, complete       2017.0
# 2  Data tabulated by year of occurrence  Final figure, complete       2017.0
# 3  Data tabulated by year of occurrence  Final figure, complete       2017.0
# 4  Data tabulated by year of occurrence  Final figure, complete       2017.0
#
#    Value Value_Footnotes
# 0  285.0             NaN
# 1    0.0             NaN
# 2    0.0             NaN
# 3    0.0             NaN
# 4    0.0             NaN

# %%
df[df.Value!=0.0]
# Out:
#               Country                                               Year  \
# 0       Åland Islands                                               2015
# 32      Åland Islands                                               2015
# 35      Åland Islands                                               2015
# 55      Åland Islands                                               2015
# 56      Åland Islands                                               2015
# 57      Åland Islands                                               2015
# 59      Åland Islands                                               2015
# 60      Åland Islands                                               2015
# 62      Åland Islands                                               2015
# 63      Åland Islands                                               2015
# 64      Åland Islands                                               2015
# 66      Åland Islands                                               2015
# ...

# %%
df.groupby('Country').Value.sum()
# Out:
# Country
# 1                                   0.000000e+00
# 10                                  0.000000e+00
# 11                                  0.000000e+00
# 12                                  0.000000e+00
# 13                                  0.000000e+00
# 14                                  0.000000e+00
# 15                                  0.000000e+00
# 16                                  0.000000e+00
# 17                                  0.000000e+00
# 18                                  0.000000e+00
# 19                                  0.000000e+00
# 2                                   0.000000e+00
# 20                                  0.000000e+00
# 21                                  0.000000e+00
# 22                                  0.000000e+00
# 23                                  0.000000e+00
# 24                                  0.000000e+00
# 3                                   0.000000e+00
# 4                                   0.000000e+00
# ...
